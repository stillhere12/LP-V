# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
cols = ["letter","x-box","y-box","width","height","onpix","x-bar","y-bar",
        "x2bar","y2bar","xybar","x2ybr","xy2br","x-ege","xegvy","y-ege","yegvx"]

df = pd.read_csv("letter-recognition.data", names=cols)

# %%
print(f"No. of Rows : {df.shape[0]}\nNo. of Columns : {df.shape[1]}\nTotal No. of Cells")
# Out:
# No. of Rows : 20000
# No. of Columns : 17
# Total No. of Cells

# %%
print("Top 5 rows")
display(df.head())
# Out:
# Top 5 rows
#   letter  x-box  y-box  width  height  onpix  x-bar  y-bar  x2bar  y2bar  \
# 0      T      2      8      3       5      1      8     13      0      6
# 1      I      5     12      3       7      2     10      5      5      4
# 2      D      4     11      6       8      6     10      6      2      6
# 3      N      7     11      6       6      3      5      9      4      6
# 4      G      2      1      3       1      1      8      6      6      6
#
#    xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0      6     10      8      0      8      0      8
# 1     13      3      9      2      8      4     10
# 2     10      3      7      3      7      3      9
# 3      4      4     10      6     10      2      8
# 4      6      5      9      1      7      5     10

# %%
print("Last 5 rows")
display(df.tail())
# Out:
# Last 5 rows
#       letter  x-box  y-box  width  height  onpix  x-bar  y-bar  x2bar  y2bar  \
# 19995      D      2      2      3       3      2      7      7      7      6
# 19996      C      7     10      8       8      4      4      8      6      9
# 19997      T      6      9      6       7      5      6     11      3      7
# 19998      S      2      3      4       2      1      8      7      2      6
# 19999      A      4      9      6       6      2      9      5      3      1
#
#        xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 19995      6      6      4      2      8      3      7
# 19996     12      9     13      2      9      3      7
# 19997     11      9      5      2     12      2      4
# 19998     10      6      8      1      9      5      8
# 19999      8      1      8      2      7      2      8

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   x-box   20000 non-null  int64
#  2   y-box   20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   x-bar   20000 non-null  int64
#  7   y-bar   20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybr   20000 non-null  int64
#  12  xy2br   20000 non-null  int64
#  13  x-ege   20000 non-null  int64
#  14  xegvy   20000 non-null  int64
#  15  y-ege   20000 non-null  int64
#  16  yegvx   20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
# None

# %%
display(df.describe())
# Out:
#               x-box         y-box         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#               x-bar         y-bar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#              x2ybr         xy2br         x-ege         xegvy         y-ege  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#              yegvx
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='letter', data=df)
plt.title("Class Distribution")
plt.show()

# %%
X = df.drop('letter', axis=1)
y = df['letter']

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
import tensorflow as tf

model = Sequential()

model.add(Dense(256, activation='elu', input_shape=(16,)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(128, activation='elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(64, activation='elu'))
model.add(BatchNormalization())

model.add(Dense(32, activation='relu'))

model.add(Dense(26, activation='softmax'))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# c:\Users\sanka\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 26)             │           858 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,234 (196.23 KB)
#  Trainable params: 49,338 (192.73 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    min_delta=0.001,
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop, lr_scheduler],
    shuffle=True
)
# Out:
# Epoch 1/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4519 - loss: 1.9648 - val_accuracy: 0.6812 - val_loss: 1.1879 - learning_rate: 5.0000e-04
# Epoch 2/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6622 - loss: 1.1652 - val_accuracy: 0.7691 - val_loss: 0.8267 - learning_rate: 5.0000e-04
# Epoch 3/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7166 - loss: 0.9507 - val_accuracy: 0.7956 - val_loss: 0.7001 - learning_rate: 5.0000e-04
# Epoch 4/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7479 - loss: 0.8303 - val_accuracy: 0.8316 - val_loss: 0.6058 - learning_rate: 5.0000e-04
# Epoch 5/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7686 - loss: 0.7562 - val_accuracy: 0.8425 - val_loss: 0.5386 - learning_rate: 5.0000e-04
# Epoch 6/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7840 - loss: 0.6951 - val_accuracy: 0.8572 - val_loss: 0.4936 - learning_rate: 5.0000e-04
# Epoch 7/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7941 - loss: 0.6704 - val_accuracy: 0.8644 - val_loss: 0.4582 - learning_rate: 5.0000e-04
# Epoch 8/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8034 - loss: 0.6249 - val_accuracy: 0.8775 - val_loss: 0.4227 - learning_rate: 5.0000e-04
# Epoch 9/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8140 - loss: 0.5859 - val_accuracy: 0.8844 - val_loss: 0.3932 - learning_rate: 5.0000e-04
# Epoch 10/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8179 - loss: 0.5734 - val_accuracy: 0.8819 - val_loss: 0.3865 - learning_rate: 5.0000e-04
# Epoch 11/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8247 - loss: 0.5519 - val_accuracy: 0.8950 - val_loss: 0.3651 - learning_rate: 5.0000e-04
# Epoch 12/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8343 - loss: 0.5259 - val_accuracy: 0.8988 - val_loss: 0.3498 - learning_rate: 5.0000e-04
# Epoch 13/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8386 - loss: 0.5125 - val_accuracy: 0.9062 - val_loss: 0.3281 - learning_rate: 5.0000e-04
# Epoch 14/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8416 - loss: 0.4984 - val_accuracy: 0.9059 - val_loss: 0.3182 - learning_rate: 5.0000e-04
# Epoch 15/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8457 - loss: 0.4836 - val_accuracy: 0.9050 - val_loss: 0.3114 - learning_rate: 5.0000e-04
# Epoch 16/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8479 - loss: 0.4777 - val_accuracy: 0.9112 - val_loss: 0.2960 - learning_rate: 5.0000e-04
# Epoch 17/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8485 - loss: 0.4671 - val_accuracy: 0.9119 - val_loss: 0.2899 - learning_rate: 5.0000e-04
# Epoch 18/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8543 - loss: 0.4552 - val_accuracy: 0.9178 - val_loss: 0.2762 - learning_rate: 5.0000e-04
# Epoch 19/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8585 - loss: 0.4344 - val_accuracy: 0.9191 - val_loss: 0.2724 - learning_rate: 5.0000e-04
# Epoch 20/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8644 - loss: 0.4175 - val_accuracy: 0.9250 - val_loss: 0.2524 - learning_rate: 5.0000e-04
# Epoch 21/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8610 - loss: 0.4228 - val_accuracy: 0.9244 - val_loss: 0.2527 - learning_rate: 5.0000e-04
# Epoch 22/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8646 - loss: 0.4204 - val_accuracy: 0.9266 - val_loss: 0.2421 - learning_rate: 5.0000e-04
# Epoch 23/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8665 - loss: 0.4111 - val_accuracy: 0.9294 - val_loss: 0.2353 - learning_rate: 5.0000e-04
# Epoch 24/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8704 - loss: 0.4042 - val_accuracy: 0.9278 - val_loss: 0.2341 - learning_rate: 5.0000e-04
# Epoch 25/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8681 - loss: 0.3998 - val_accuracy: 0.9306 - val_loss: 0.2292 - learning_rate: 5.0000e-04
# Epoch 26/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8743 - loss: 0.3903 - val_accuracy: 0.9334 - val_loss: 0.2186 - learning_rate: 5.0000e-04
# Epoch 27/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8763 - loss: 0.3736 - val_accuracy: 0.9366 - val_loss: 0.2167 - learning_rate: 5.0000e-04
# Epoch 28/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8768 - loss: 0.3763 - val_accuracy: 0.9341 - val_loss: 0.2160 - learning_rate: 5.0000e-04
# Epoch 29/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8827 - loss: 0.3676 - val_accuracy: 0.9347 - val_loss: 0.2108 - learning_rate: 5.0000e-04
# Epoch 30/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8764 - loss: 0.3693 - val_accuracy: 0.9359 - val_loss: 0.2098 - learning_rate: 5.0000e-04
# Epoch 31/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8799 - loss: 0.3687 - val_accuracy: 0.9375 - val_loss: 0.2025 - learning_rate: 5.0000e-04
# Epoch 32/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8837 - loss: 0.3543 - val_accuracy: 0.9384 - val_loss: 0.1986 - learning_rate: 5.0000e-04
# Epoch 33/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8877 - loss: 0.3374 - val_accuracy: 0.9362 - val_loss: 0.2040 - learning_rate: 5.0000e-04
# Epoch 34/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8905 - loss: 0.3377 - val_accuracy: 0.9394 - val_loss: 0.1995 - learning_rate: 5.0000e-04
# Epoch 35/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8833 - loss: 0.3472 - val_accuracy: 0.9381 - val_loss: 0.1964 - learning_rate: 5.0000e-04
# Epoch 36/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8888 - loss: 0.3335 - val_accuracy: 0.9403 - val_loss: 0.1894 - learning_rate: 5.0000e-04
# Epoch 37/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8875 - loss: 0.3413 - val_accuracy: 0.9428 - val_loss: 0.1857 - learning_rate: 5.0000e-04
# Epoch 38/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8927 - loss: 0.3295 - val_accuracy: 0.9466 - val_loss: 0.1843 - learning_rate: 5.0000e-04
# Epoch 39/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8938 - loss: 0.3220 - val_accuracy: 0.9484 - val_loss: 0.1765 - learning_rate: 5.0000e-04
# Epoch 40/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8930 - loss: 0.3207 - val_accuracy: 0.9453 - val_loss: 0.1721 - learning_rate: 5.0000e-04
# Epoch 41/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8966 - loss: 0.3127 - val_accuracy: 0.9463 - val_loss: 0.1763 - learning_rate: 5.0000e-04
# Epoch 42/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8991 - loss: 0.3107 - val_accuracy: 0.9456 - val_loss: 0.1705 - learning_rate: 5.0000e-04
# Epoch 43/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9006 - loss: 0.3084 - val_accuracy: 0.9453 - val_loss: 0.1709 - learning_rate: 5.0000e-04
# Epoch 44/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8959 - loss: 0.3223 - val_accuracy: 0.9506 - val_loss: 0.1686 - learning_rate: 5.0000e-04
# Epoch 45/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8950 - loss: 0.3077 - val_accuracy: 0.9481 - val_loss: 0.1649 - learning_rate: 5.0000e-04
# Epoch 46/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8968 - loss: 0.3053 - val_accuracy: 0.9463 - val_loss: 0.1701 - learning_rate: 5.0000e-04
# Epoch 47/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9023 - loss: 0.2998 - val_accuracy: 0.9475 - val_loss: 0.1623 - learning_rate: 5.0000e-04
# Epoch 48/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9019 - loss: 0.2937 - val_accuracy: 0.9516 - val_loss: 0.1597 - learning_rate: 5.0000e-04
# Epoch 49/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9024 - loss: 0.2969 - val_accuracy: 0.9472 - val_loss: 0.1611 - learning_rate: 5.0000e-04
# Epoch 50/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8995 - loss: 0.3040 - val_accuracy: 0.9491 - val_loss: 0.1579 - learning_rate: 5.0000e-04
# Epoch 51/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9060 - loss: 0.2861 - val_accuracy: 0.9516 - val_loss: 0.1580 - learning_rate: 5.0000e-04
# Epoch 52/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9014 - loss: 0.2936 - val_accuracy: 0.9519 - val_loss: 0.1574 - learning_rate: 5.0000e-04
# Epoch 53/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9020 - loss: 0.2864 - val_accuracy: 0.9534 - val_loss: 0.1557 - learning_rate: 5.0000e-04
# Epoch 54/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9055 - loss: 0.2773 - val_accuracy: 0.9528 - val_loss: 0.1552 - learning_rate: 5.0000e-04
# Epoch 55/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9038 - loss: 0.2877 - val_accuracy: 0.9519 - val_loss: 0.1573 - learning_rate: 5.0000e-04
# Epoch 56/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9030 - loss: 0.2875 - val_accuracy: 0.9550 - val_loss: 0.1505 - learning_rate: 5.0000e-04
# Epoch 57/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9061 - loss: 0.2763 - val_accuracy: 0.9544 - val_loss: 0.1535 - learning_rate: 5.0000e-04
# Epoch 58/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9091 - loss: 0.2775 - val_accuracy: 0.9519 - val_loss: 0.1543 - learning_rate: 5.0000e-04
# Epoch 59/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9078 - loss: 0.2735 - val_accuracy: 0.9581 - val_loss: 0.1411 - learning_rate: 5.0000e-04
# Epoch 60/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9056 - loss: 0.2724 - val_accuracy: 0.9531 - val_loss: 0.1505 - learning_rate: 5.0000e-04
# Epoch 61/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9104 - loss: 0.2675 - val_accuracy: 0.9544 - val_loss: 0.1457 - learning_rate: 5.0000e-04
# Epoch 62/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9092 - loss: 0.2756 - val_accuracy: 0.9544 - val_loss: 0.1436 - learning_rate: 5.0000e-04
# Epoch 63/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9133 - loss: 0.2570 - val_accuracy: 0.9553 - val_loss: 0.1392 - learning_rate: 2.5000e-04
# Epoch 64/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9150 - loss: 0.2486 - val_accuracy: 0.9588 - val_loss: 0.1355 - learning_rate: 2.5000e-04
# Epoch 65/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9166 - loss: 0.2459 - val_accuracy: 0.9594 - val_loss: 0.1355 - learning_rate: 2.5000e-04
# Epoch 66/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9176 - loss: 0.2443 - val_accuracy: 0.9597 - val_loss: 0.1309 - learning_rate: 2.5000e-04
# Epoch 67/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9202 - loss: 0.2425 - val_accuracy: 0.9591 - val_loss: 0.1311 - learning_rate: 2.5000e-04
# Epoch 68/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9229 - loss: 0.2320 - val_accuracy: 0.9638 - val_loss: 0.1305 - learning_rate: 2.5000e-04
# Epoch 69/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9205 - loss: 0.2405 - val_accuracy: 0.9594 - val_loss: 0.1326 - learning_rate: 2.5000e-04
# Epoch 70/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9199 - loss: 0.2405 - val_accuracy: 0.9566 - val_loss: 0.1340 - learning_rate: 2.5000e-04
# Epoch 71/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9222 - loss: 0.2405 - val_accuracy: 0.9603 - val_loss: 0.1291 - learning_rate: 2.5000e-04
# Epoch 72/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9224 - loss: 0.2332 - val_accuracy: 0.9631 - val_loss: 0.1288 - learning_rate: 2.5000e-04
# Epoch 73/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9199 - loss: 0.2379 - val_accuracy: 0.9594 - val_loss: 0.1299 - learning_rate: 2.5000e-04
# Epoch 74/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9182 - loss: 0.2423 - val_accuracy: 0.9594 - val_loss: 0.1285 - learning_rate: 2.5000e-04
# Epoch 75/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9180 - loss: 0.2401 - val_accuracy: 0.9609 - val_loss: 0.1240 - learning_rate: 2.5000e-04
# Epoch 76/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9228 - loss: 0.2362 - val_accuracy: 0.9619 - val_loss: 0.1256 - learning_rate: 2.5000e-04
# Epoch 77/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9225 - loss: 0.2343 - val_accuracy: 0.9634 - val_loss: 0.1270 - learning_rate: 2.5000e-04
# Epoch 78/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9181 - loss: 0.2452 - val_accuracy: 0.9622 - val_loss: 0.1258 - learning_rate: 2.5000e-04
# Epoch 79/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9241 - loss: 0.2264 - val_accuracy: 0.9641 - val_loss: 0.1247 - learning_rate: 1.2500e-04
# Epoch 80/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9247 - loss: 0.2229 - val_accuracy: 0.9622 - val_loss: 0.1256 - learning_rate: 1.2500e-04

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1178
# Test Accuracy: 0.965749979019165

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Accuracy:", accuracy_score(y_true, y_pred_classes))
print(classification_report(y_true, y_pred_classes))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.96575
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       149
#            1       0.92      0.92      0.92       153
#            2       0.98      0.95      0.96       137
#            3       0.94      0.97      0.96       156
#            4       0.97      0.99      0.98       141
#            5       0.96      0.99      0.97       140
#            6       0.97      0.98      0.98       160
#            7       0.93      0.90      0.91       144
#            8       0.97      0.96      0.97       146
#            9       0.96      0.96      0.96       149
#           10       0.96      0.93      0.95       130
#           11       0.98      0.97      0.97       155
#           12       0.98      1.00      0.99       168
#           13       0.99      0.97      0.98       151
#           14       0.93      0.97      0.95       145
#           15       0.99      0.97      0.98       173
#           16       0.99      0.98      0.98       166
#           17       0.90      0.92      0.91       160
#           18       0.98      0.98      0.98       171
#           19       0.98      0.98      0.98       163
#           20       0.96      0.98      0.97       183
#           21       0.96      0.95      0.95       158
#           22       0.99      0.96      0.98       148
#           23       0.98      0.99      0.99       154
#           24       0.99      0.98      0.98       168
#           25       0.98      0.96      0.97       132
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000

# %%
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
